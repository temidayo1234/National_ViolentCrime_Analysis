# %%
# This code creates chartes from demographic datasets
# We will chart the following demographics against the Low Crime data and High Crime data
# The demographic data points are:
#     Income level
#     Population
#     Marital Status
#     Race
#     Education level
#     School Enrollment Status
#     Unemployment level

# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read Low Crime Income Level csv into a new dataframe
lowcrime_income_df = pd.read_csv('Low Crime/Data/incomecrime.csv')
lowcrime_income_df
# Out:
#              State  Median Income
# 0          Alabama          29703
# 1           Alaska          25682
# 2          Arizona          29303
# 3         Arkansas          24246
# 4         Colorado          42518
# 5         Delaware          32500
# 6            Idaho          17338
# 7          Indiana          35377
# 8           Kansas          56239
# 9        Louisiana          19889
# 10           Maine          24536
# 11       Minnesota          41803
# 12        Missouri          33275
# 13         Montana          50033
# 14        Nebraska          24342
# 15          Nevada          16994
# 16  North Carolina          20269
# 17    North Dakota          27296
# 18  South Carolina          60007
# 19    South Dakota          37083
# 20       Tennessee          25510
# 21           Texas          54373
# 22            Utah          27902
# 23         Vermont          28415
# 24        Virginia          24023
# 25      Washington          30753
# 26   West Virginia          30263

# %%
# Display a scatter chart showing states on the x_axis and median income on the y-axis
# Use Matplotlib

# Set x axis and tick locations
x_axis = np.arange(len(lowcrime_income_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.scatter(x_axis, lowcrime_income_df["Median Income"], color='g', alpha=0.75)
plt.xticks(tick_locations, lowcrime_income_df["State"], rotation="vertical")

# Add Title and Labels to chart
plt.title("Median Income for Lowest Crime Rate City Within Each State")
plt.ylabel("Median Income (in dollars)")

# Save Low Crime - Income scatter chart
plt.tight_layout()
plt.savefig("Low Crime/Results/lowcrime_income.png")

# Matplotlib bar chart of income
# Set x axis and tick locations
#x_axis = np.arange(len(lowcrime_income_df))
#tick_locations = [value+0.4 for value in x_axis]

# Create a list indicating where to write x labels and set figure size to adjust for space
#plt.figure(figsize=(20,3))
#plt.bar(x_axis, lowcrime_income_df["Median Income"], color='g', alpha=0.5, align="edge")
#plt.xticks(tick_locations, lowcrime_income_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Read High Crime Income Level csv into a new dataframe
highcrime_income_df = pd.read_csv('High Crime/Data/incomecrime.csv')
highcrime_income_df
# Out:
#              State  Median Income
# 0          Alabama        16810.0
# 1           Alaska        27756.0
# 2          Arizona        18516.0
# 3         Arkansas        16574.0
# 4      Connecticut        18205.0
# 5          Florida        12258.0
# 6            Idaho        19231.0
# 7         Illinois        16303.0
# 8          Indiana        20759.0
# 9             Iowa        19870.0
# 10          Kansas        26213.0
# 11        Kentucky        19701.0
# 12        Maryland        25071.0
# 13       Minnesota        18025.0
# 14     Mississippi        19317.0
# 15        Missouri        12750.0
# 16        Nebraska        32405.0
# 17   New Hampshire        27083.0
# 18        New York        20210.0
# 19  North Carolina        17851.0
# 20    North Dakota        35718.0
# 21            Ohio        20243.0
# 22        Oklahoma        22610.0
# 23          Oregon        23895.0
# 24    Pennsylvania        20030.0
# 25    Rhode Island        16240.0
# 26  South Carolina        18776.0
# 27    South Dakota        22097.0
# 28       Tennessee        15848.0
# 29      Washington        32068.0
# 30   West Virginia        20776.0
# 31       Wisconsin        21396.0

# %%
# Display a scatter chart showing states on the x_axis and median income on the y-axis
# Use Matplotlib

# Set x axis and tick locations
x_axis = np.arange(len(highcrime_income_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.scatter(x_axis, highcrime_income_df["Median Income"], color='g', alpha=0.75)
plt.xticks(tick_locations, highcrime_income_df["State"], rotation="vertical")

# Add Title and Labels to chart
plt.title("Median Income for Highest Crime Rate City Within Each State")
plt.ylabel("Median Income (in dollars)")

# Save High Crime - Income scatter chart
plt.tight_layout()
plt.savefig("High Crime/Results/highcrime_income.png")
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Read Low Crime Population csv into a new dataframe
lowcrime_population_df = pd.read_csv('Low Crime/Data/totalpopulation.csv')
lowcrime_population_df
# Out:
#              State  Population
# 0          Alabama        4146
# 1           Alaska        2387
# 2          Arizona       57165
# 3         Arkansas        5090
# 4       California       11253
# 5         Colorado       10186
# 6         Delaware        1880
# 7          Florida       27114
# 8          Georgia        4422
# 9            Idaho        5362
# 10        Illinois       41591
# 11         Indiana       16257
# 12            Iowa       10316
# 13          Kansas        3964
# 14        Kentucky       16326
# 15       Louisiana        3401
# 16           Maine        7233
# 17        Maryland        4814
# 18        Michigan       10403
# 19       Minnesota       25951
# 20     Mississippi        4014
# 21        Missouri        7577
# 22         Montana        2289
# 23        Nebraska        1716
# 24          Nevada        3021
# 25      New Mexico        2227
# 26        New York       15944
# 27  North Carolina        4471
# 28    North Dakota        2306
# 29        Oklahoma        5173
# 30          Oregon        3070
# 31  South Carolina        8609
# 32    South Dakota        4427
# 33       Tennessee       29310
# 34           Texas       24101
# 35            Utah       10054
# 36         Vermont         630
# 37        Virginia        5844
# 38      Washington        7531
# 39   West Virginia        5587
# 40       Wisconsin       18255
# 41         Wyoming        5416

# %%
# Display a scatter chart showing states on the x_axis and total population on the y-axis
# Use Matplotlib

# Set x axis and tick locations
x_axis = np.arange(len(lowcrime_population_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.scatter(x_axis, lowcrime_population_df["Population"], color='k', alpha=0.75)
plt.xticks(tick_locations, lowcrime_population_df["State"], rotation="vertical")

# Add Title and Labels to chart
plt.title("Total Population for Lowest Crime Rate City Within Each State")
plt.ylabel("Total Population")

# Save Low Crime - Income scatter chart
plt.tight_layout()
plt.savefig("Low Crime/Results/lowcrime_population.png")
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Read High Crime Population csv into a new dataframe
highcrime_population_df = pd.read_csv('High Crime/Data/totalpopulation.csv')
highcrime_population_df
# Out:
#              State  Population
# 0          Alabama     22626.0
# 1           Alaska      3283.0
# 2          Arizona      3639.0
# 3         Arkansas      7424.0
# 4       California       433.0
# 5      Connecticut    124795.0
# 6         Delaware       250.0
# 7          Florida     12024.0
# 8          Georgia     14026.0
# 9            Idaho      1329.0
# 10        Illinois      2758.0
# 11         Indiana     52354.0
# 12            Iowa     10705.0
# 13          Kansas    387147.0
# 14        Kentucky      1196.0
# 15       Louisiana     49529.0
# 16           Maine      1574.0
# 17        Maryland    622454.0
# 18        Michigan     10014.0
# 19       Minnesota       847.0
# 20     Mississippi      7572.0
# 21        Missouri       267.0
# 22         Montana      1858.0
# 23        Nebraska      6830.0
# 24   New Hampshire       761.0
# 25      New Jersey        85.0
# 26      New Mexico       725.0
# 27        New York     28495.0
# 28  North Carolina     21721.0
# 29    North Dakota      3728.0
# 30            Ohio    282275.0
# 31        Oklahoma     24955.0
# 32          Oregon      1402.0
# 33    Pennsylvania     10693.0
# 34    Rhode Island     19378.0
# 35  South Carolina      2244.0
# 36    South Dakota       954.0
# 37       Tennessee      9036.0
# 38           Texas     11616.0
# 39            Utah        60.0
# 40         Vermont      6864.0
# 41        Virginia     32123.0
# 42      Washington      9477.0
# 43   West Virginia     17375.0
# 44       Wisconsin    599498.0
# 45         Wyoming      2836.0

# %%
# Display a scatter chart showing states on the x_axis and total population on the y-axis
# Use Matplotlib

# Set x axis and tick locations
x_axis = np.arange(len(highcrime_population_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.scatter(x_axis, highcrime_population_df["Population"], color='k', alpha=0.75)
plt.xticks(tick_locations, highcrime_population_df["State"], rotation="vertical")

# Add Title and Labels to chart
plt.title("Total Population for Highest Crime Rate City Within Each State")
plt.ylabel("Total Population")

# Save Low Crime - Income scatter chart
plt.tight_layout()
plt.savefig("high Crime/Results/highcrime_population.png")
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Read Low Crime Unemployment Level csv into a new dataframe
lowcrime_unemployment_df = pd.read_csv('Low Crime/Data/unemploymentcrime.csv')
lowcrime_unemployment_df
# Out:
#              State  % Unemployment
# 0          Alabama            5.05
# 1           Alaska            4.33
# 2          Arizona            4.15
# 3         Arkansas            4.27
# 4       California            3.33
# 5         Colorado            3.38
# 6         Delaware            4.61
# 7          Florida            4.01
# 8          Georgia            5.71
# 9            Idaho            4.68
# 10         Indiana            5.89
# 11            Iowa            2.76
# 12          Kansas            1.86
# 13        Kentucky            3.53
# 14       Louisiana            4.00
# 15           Maine            3.72
# 16        Maryland            1.97
# 17       Minnesota            1.92
# 18     Mississippi            2.80
# 19        Missouri            1.93
# 20         Montana            4.42
# 21        Nebraska            2.06
# 22          Nevada            7.44
# 23      New Mexico            2.71
# 24        New York            3.22
# 25  North Carolina            5.20
# 26    North Dakota            2.86
# 27        Oklahoma            4.85
# 28          Oregon            1.64
# 29  South Carolina            4.10
# 30    South Dakota            2.26
# 31       Tennessee            5.66
# 32           Texas            2.26
# 33            Utah            4.61
# 34         Vermont            2.16
# 35        Virginia            1.91
# 36      Washington            2.25
# 37   West Virginia            7.20
# 38       Wisconsin            3.53
# 39         Wyoming            5.77

# %%
# Display a scatter chart showing states on the x_axis and unemployment level on the y-axis
# Use Matplotlib

# Set x axis and tick locations
x_axis = np.arange(len(lowcrime_unemployment_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.scatter(x_axis, lowcrime_unemployment_df["% Unemployment"], color='b', alpha=0.75)
plt.xticks(tick_locations, lowcrime_unemployment_df["State"], rotation="vertical")

# Add Title and Labels to chart
plt.title("Unemployment Level for Lowest Crime Rate City Within Each State")
plt.ylabel("Unemployment Level")

# Save Low Crime - Income scatter chart
plt.tight_layout()
plt.savefig("Low Crime/Results/lowcrime_unemployment.png")
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Read High Crime Unemployment Level csv into a new dataframe
highcrime_unemployment_df = pd.read_csv('High Crime/Data/unemploymentcrime.csv')
highcrime_unemployment_df
# Out:
#              State  % Unemployment
# 0          Alabama            8.37
# 1           Alaska            9.88
# 2          Arizona            5.00
# 3         Arkansas           13.23
# 4       California            5.52
# 5      Connecticut           12.05
# 6         Delaware            0.42
# 7          Florida           15.30
# 8          Georgia           10.02
# 9            Idaho            6.50
# 10        Illinois           10.67
# 11         Indiana            6.87
# 12            Iowa            6.32
# 13          Kansas            4.99
# 14        Kentucky            7.66
# 15       Louisiana            7.51
# 16           Maine            6.31
# 17        Maryland            8.08
# 18        Michigan           13.47
# 19       Minnesota            9.38
# 20     Mississippi            4.70
# 21        Missouri           14.54
# 22         Montana            7.05
# 23        Nebraska            0.72
# 24   New Hampshire            9.29
# 25      New Jersey            2.74
# 26        New York            7.27
# 27  North Carolina            4.94
# 28    North Dakota            1.07
# 29            Ohio            8.47
# 30        Oklahoma            4.20
# 31          Oregon           10.54
# 32    Pennsylvania            8.48
# 33    Rhode Island            8.10
# 34  South Carolina            5.55
# 35    South Dakota            4.66
# 36       Tennessee            8.68
# 37           Texas            9.72
# 38            Utah           13.04
# 39         Vermont            4.65
# 40        Virginia            7.36
# 41      Washington            6.09
# 42   West Virginia            4.42
# 43       Wisconsin            7.67
# 44         Wyoming            7.26

# %%
# Display a scatter chart showing states on the x_axis and unemployment level on the y-axis
# Use Matplotlib

# Set x axis and tick locations
x_axis = np.arange(len(highcrime_unemployment_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.scatter(x_axis, highcrime_unemployment_df["% Unemployment"], color='b', alpha=0.75)
plt.xticks(tick_locations, highcrime_unemployment_df["State"], rotation="vertical")

# Add Title and Labels to chart
plt.title("Unemployment Level for Highest Crime Rate City Within Each State")
plt.ylabel("Unemployment Level")

# Save Low Crime - Income scatter chart
plt.tight_layout()
plt.savefig("High Crime/Results/highcrime_unemployment.png")
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Read Low Crime Marital Status csv into a new dataframe
lowcrime_marital_df = pd.read_csv('Low Crime/Data/maritalstatuscrime.csv')
lowcrime_marital_df
# Out:
#              State  % Never Married  % Married  % Divorced  % Separated  \
# 0          Alabama            16.33      59.38       17.75         4.36
# 1           Alaska            23.13      51.21       17.17         1.75
# 2          Arizona            33.39      50.06       10.77         1.66
# 3         Arkansas            19.20      63.10        9.82         1.60
# 4       California            20.84      71.74        2.96         0.68
# 5         Colorado            20.62      64.64       11.80         0.48
# 6         Delaware            16.03      65.02       13.73         1.68
# 7          Florida            24.59      63.55        7.01         0.88
# 8          Georgia            32.31      34.97       14.76         5.79
# 9            Idaho            23.27      49.21       14.67         3.85
# 10         Indiana            27.71      56.66        7.72         0.99
# 11            Iowa            33.22      53.05        6.19         0.79
# 12          Kansas            27.53      51.82       12.58         1.96
# 13        Kentucky            27.18      53.35       12.24         1.15
# 14       Louisiana            19.12      56.97        7.19         5.23
# 15           Maine            28.26      40.32       21.99         0.59
# 16        Maryland            24.87      58.77        9.18         0.88
# 17       Minnesota            25.63      58.66       10.45         0.48
# 18     Mississippi            39.39      33.40       13.56         2.55
# 19        Missouri            16.19      64.74       12.50         1.60
# 20         Montana            18.36      67.26       10.22         0.95
# 21        Nebraska            27.74      52.21       10.68         0.36
# 22          Nevada            29.61      34.40       19.92         5.10
# 23      New Mexico            29.70      42.04       17.30         2.13
# 24        New York            20.76      65.62        5.58         1.91
# 25  North Carolina            19.26      50.72       12.73         4.39
# 26    North Dakota            47.99      31.78       14.40         2.16
# 27        Oklahoma            21.95      57.30       15.72         0.28
# 28          Oregon            16.94      51.09       21.48         1.98
# 29  South Carolina            21.51      69.66        4.31         2.16
# 30    South Dakota            23.14      63.69        7.47         2.61
# 31       Tennessee            27.89      48.64       14.11         2.14
# 32           Texas            35.48      55.91        5.90         0.51
# 33            Utah            26.39      65.53        4.67         1.41
# 34         Vermont            47.25      28.39       15.04         7.20
# 35        Virginia            38.14      45.39        6.65         0.00
# 36      Washington            25.73      51.66       12.20         3.20
# 37   West Virginia            22.23      55.08       15.15         0.14
# 38       Wisconsin            25.68      56.87        9.62         1.13
# 39         Wyoming            19.33      49.80       20.77         1.60
#
#     % Widowed
# 0        2.18
# 1        6.74
# 2        4.12
# 3        6.29
# 4        3.77
# 5        2.46
# 6        3.53
# 7        3.98
# 8       12.18
# 9        9.01
# 10       6.92
# 11       6.75
# 12       6.10
# 13       6.08
# 14      11.48
# 15       8.84
# 16       6.30
# 17       4.78
# 18      11.10
# 19       4.96
# 20       3.21
# 21       9.01
# 22      10.97
# 23       8.82
# 24       6.12
# 25      12.89
# 26       3.67
# 27       4.76
# 28       8.51
# 29       2.36
# 30       3.09
# 31       7.22
# 32       2.20
# 33       2.00
# 34       2.12
# 35       9.82
# 36       7.21
# 37       7.40
# 38       6.69
# 39       8.50

# %%
# Display a stacked bar chart showing states on the x_axis and 100 on on the y-axis
# The marital status types will make up the bar stacks
# Use Matplotlib horizontal bar chart showing discrete distributions

# Get the list of marital status categories into a Series data structure
# This list is needed for creating the horizontal stacked bar chart in Matplotlib
category_names = lowcrime_marital_df.iloc[0]
category_names = category_names.drop('State')
category_names.index

# Set x axis and tick locations
x_axis = np.arange(len(lowcrime_marital_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
# Tell matplotlib that we will be making a bar chart
# Marital Status is our y axis and State Name, listed vertically, is our x axis
# We apply align="edge" to ensure our bars line up with our tick marks
x_axis = lowcrime_marital_df['State']
#x_axis = np.arange(len(lowcrime_marital_df['State'])

plt.bar(x_axis, 100, color='b', alpha=0.5, align="center")

plt.xticks(tick_locations, lowcrime_marital_df["State"], rotation="vertical")

# Add Title and Labels to chart
plt.title("Marital Status for Lowest Crime Rate City Within Each State")
plt.ylabel("Marital Status Proportion")



#------------------------------------------------------------------------------

#THIS IS TNE NEW CODE FROM THE MATPLOTLIB WEBSITE
#IT USES LISTS, NOT DATAFRAMES; FIGURE OUT HOW TO USE THIS CODE WITH DATAFRAMES

#category_names = ['Strongly disagree', 'Disagree',
#                  'Neither agree nor disagree', 'Agree', 'Strongly agree']
#results = {
#    'Question 1': [10, 15, 17, 32, 26],
#    'Question 2': [26, 22, 29, 10, 13],
#    'Question 3': [35, 37, 7, 2, 19],
#    'Question 4': [32, 11, 9, 15, 33],
#    'Question 5': [21, 29, 5, 5, 40],
#    'Question 6': [8, 19, 5, 30, 38]
#}

#def survey(results, category_names):
#    """
#    Parameters
#    ----------
#    results : dict
#        A mapping from question labels to a list of answers per category.
#        It is assumed all lists contain the same number of entries and that
#        it matches the length of *category_names*.
#    category_names : list of str
#        The category labels.
#    """

#labels = list(results.keys())
#data = np.array(list(results.values()))
#data_cum = data.cumsum(axis=1)
#category_colors = plt.get_cmap('RdYlGn')(np.linspace(0.15, 0.85, data.shape[1]))

#fig, ax = plt.subplots(figsize=(9.2, 5))
#ax.invert_yaxis()
#ax.xaxis.set_visible(False)
#ax.set_xlim(0, np.sum(data, axis=1).max())

#for i, (colname, color) in enumerate(zip(category_names, category_colors)):
#    widths = data[:, i]
#    starts = data_cum[:, i] - widths
#    ax.barh(labels, widths, left=starts, height=0.5,
#            label=colname, color=color)
#    xcenters = starts + widths / 2

#    r, g, b, _ = color
#    text_color = 'white' if r * g * b < 0.5 else 'darkgrey'
#    for y, (x, c) in enumerate(zip(xcenters, widths)):
#        ax.text(x, y, str(int(c)), ha='center', va='center',
#                color=text_color)
#ax.legend(ncol=len(category_names), bbox_to_anchor=(0, 1),
#          loc='lower left', fontsize='small')

#return fig, ax

#survey(results, category_names)

#------------------------------------------------------------------------------

# BACK TO MY CODE
plt.show()

plt.tight_layout()
#plt.savefig("Low Crime/Results/lowcrime_marital_plt.png")
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Display a stacked bar chart showing states on the x_axis and 100 on on the y-axis
# The marital status types will make up the bar stacks
# Use Matplotlib horizontal bar chart showing discrete distributions

# Get the list of marital status categories into a Series data structure
# This list is needed for creating the horizontal stacked bar chart in Matplotlib
category_names = lowcrime_marital_df.iloc[0]
category_names = category_names.drop('State')
category_names.index

# Set x axis and tick locations
x_axis = np.arange(len(lowcrime_marital_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
# Tell matplotlib that we will be making a bar chart
# Marital Status proportion (totaling 100%) is our y axis and State Name, listed vertically, is our x axis
# We apply align="edge" to ensure our bars line up with our tick marks
x_axis = lowcrime_marital_df['State']
#x_axis = np.arange(len(lowcrime_marital_df['State'])

plt.bar(x_axis, 100, color='b', alpha=0.5, align="center")

plt.xticks(tick_locations, lowcrime_marital_df["State"], rotation="vertical")

# Add Title and Labels to chart
plt.title("Marital Status for Lowest Crime Rate City Within Each State")
plt.ylabel("Marital Status Proportion")





#THE REST OF THIS IS TNE NEW CODE FROM THE MATPLOTLIB WEBSITE
#IT USES LISTS, NOT DATAFRAMES; FIGURE OUT HOW TO USE THIS CODE WITH DATAFRAMES
#labels = list(results.keys())
#data = np.array(list(results.values()))
#data_cum = data.cumsum(axis=1)
#category_colors = plt.get_cmap('RdYlGn')(np.linspace(0.15, 0.85, data.shape[1]))

#fig, ax = plt.subplots(figsize=(9.2, 5))
#ax.invert_yaxis()
#ax.xaxis.set_visible(False)
#ax.set_xlim(0, np.sum(data, axis=1).max())

#for i, (colname, color) in enumerate(zip(category_names, category_colors)):
#    widths = data[:, i]
#    starts = data_cum[:, i] - widths
#    ax.barh(labels, widths, left=starts, height=0.5,
#            label=colname, color=color)
#    xcenters = starts + widths / 2

#    r, g, b, _ = color
#    text_color = 'white' if r * g * b < 0.5 else 'darkgrey'
#    for y, (x, c) in enumerate(zip(xcenters, widths)):
#        ax.text(x, y, str(int(c)), ha='center', va='center',
#                color=text_color)
#ax.legend(ncol=len(category_names), bbox_to_anchor=(0, 1),
#          loc='lower left', fontsize='small')

#return fig, ax

#survey(results, category_names)
plt.show()

plt.tight_layout()
#plt.savefig("Low Crime/Results/lowcrime_marital_horizplt.png")
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Display a stacked bar chart showing states on the x_axis and 100 on on the y-axis
# The marital status types will make up the bar stacks
# Using Pandas to display horizontal bar chart showing discrete distributions

# Set x axis and tick locations
x_axis = np.arange(len(lowcrime_marital_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
x_axis = lowcrime_marital_df['State']
lowcrime_marital_df.plot.bar(stacked=True)

plt.xticks(tick_locations, lowcrime_marital_df["State"], rotation="vertical")

# Add Title and Labels to chart
plt.title("Marital Status for Lowest Crime Rate City Within Each State")
plt.ylabel("Proportionate Marital Status")

# Save as a pd chart
plt.savefig("Low Crime/Results/lowcrime_marital.png")
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Read High Crime Marital Status csv into a new dataframe
highcrime_marital_df = pd.read_csv('High Crime/Data/maritalstatuscrime.csv')
highcrime_marital_df
# Out:
#              State  % Never Married  % Married  % Divorced  % Separated  \
# 0          Alabama            32.45      37.47       13.77         5.07
# 1           Alaska            45.13      43.11        7.38         1.24
# 2          Arizona            27.87      47.23       15.97         1.26
# 3         Arkansas            31.80      40.49       15.33         5.84
# 4       California            36.61      57.29        2.71         2.03
# 5      Connecticut            56.24      24.44       10.88         3.92
# 6         Delaware            18.14      54.01       12.24         0.42
# 7          Florida            56.34      25.41        7.94         5.20
# 8          Georgia            55.01      23.02       12.20         3.53
# 9            Idaho            20.21      49.95       21.81         1.32
# 10        Illinois            39.55      25.87       13.54         9.13
# 11         Indiana            35.83      39.36       15.64         2.34
# 12            Iowa            31.00      44.63       16.38         1.25
# 13          Kansas            32.52      46.98       13.05         1.96
# 14        Kentucky            47.66      28.45       14.85         4.36
# 15       Louisiana            47.91      28.91       11.98         3.83
# 16           Maine            34.04      32.90       18.84         2.20
# 17        Maryland            51.95      26.60       11.01         3.83
# 18        Michigan            55.87      20.19       14.15         3.55
# 19       Minnesota            43.56      24.60       19.54         4.49
# 20     Mississippi            55.32      21.40        9.74         5.28
# 21        Missouri            60.68      15.38       13.25         7.69
# 22         Montana            31.82      41.05       18.39         2.24
# 23        Nebraska            21.55      52.01       15.68         2.12
# 24   New Hampshire            31.86      39.57       15.86         2.29
# 25      New Jersey            13.70      46.58       23.29         2.74
# 26        New York            49.68      32.95        7.32         4.71
# 27  North Carolina            39.90      35.80       11.26         4.29
# 28    North Dakota            26.16      58.65        7.99         1.04
# 29            Ohio            41.72      34.38       14.86         2.38
# 30        Oklahoma            29.43      42.81       16.58         1.45
# 31          Oregon            20.75      57.69       13.33         1.70
# 32    Pennsylvania            49.60      23.87        9.49         8.49
# 33    Rhode Island            46.64      32.93       10.55         4.92
# 34  South Carolina            41.50      36.07        4.74         3.41
# 35    South Dakota            28.96      46.13       13.11         1.70
# 36       Tennessee            40.93      28.18       14.59         4.95
# 37           Texas            35.46      41.09       10.19         3.77
# 38            Utah            33.33      35.29       13.73         0.00
# 39         Vermont            33.50      41.75       17.34         1.12
# 40        Virginia            47.02      29.45       11.17         4.51
# 41      Washington            35.53      43.78       14.83         2.38
# 42   West Virginia            31.21      40.68       14.87         2.13
# 43       Wisconsin            51.67      30.41       10.75         2.38
# 44         Wyoming            26.75      48.19       18.91         1.41
#
#     % Widowed
# 0       11.25
# 1        3.14
# 2        7.67
# 3        6.55
# 4        1.36
# 5        4.51
# 6       15.19
# 7        5.10
# 8        6.23
# 9        6.70
# 10      11.91
# 11       6.83
# 12       6.74
# 13       5.50
# 14       4.67
# 15       7.38
# 16      12.01
# 17       6.61
# 18       6.24
# 19       7.81
# 20       8.26
# 21       2.99
# 22       6.50
# 23       8.64
# 24      10.43
# 25      13.70
# 26       5.35
# 27       8.75
# 28       6.16
# 29       6.66
# 30       9.73
# 31       6.53
# 32       8.54
# 33       4.95
# 34      14.28
# 35      10.09
# 36      11.34
# 37       9.50
# 38      17.65
# 39       6.29
# 40       7.84
# 41       3.47
# 42      11.11
# 43       4.78
# 44       4.74

# %%
# Display a stacked bar chart showing states on the x_axis and 100 on on the y-axis
# The marital status types will make up the bar stacks
# Using Pandas to display horizontal bar chart showing discrete distributions

# Set x axis and tick locations
x_axis = np.arange(len(highcrime_marital_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
x_axis = highcrime_marital_df['State']
highcrime_marital_df.plot.bar(stacked=True)

plt.xticks(tick_locations, highcrime_marital_df["State"], rotation="vertical")

# Add Title and Labels to chart
plt.title("Marital Status for Highest Crime Rate City Within Each State")
plt.ylabel("Proportionate Marital Status")

# Save as a pd chart
plt.savefig("High Crime/Results/highcrime_marital.png")
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Read Low Crime Education Level csv into a new dataframe
lowcrime_education_df = pd.read_csv('Low Crime/Data/educationcrime.csv')
lowcrime_education_df
# Out:
#              State  % None  % High School  % Associates  % Bachelors  \
# 0          Alabama   12.48          32.48         36.51         7.93
# 1           Alaska    9.85          35.59         34.71        14.41
# 2          Arizona   15.68          28.00         40.17        12.37
# 3         Arkansas   10.56          31.94         39.99        12.70
# 4       California    2.43           5.53         13.44        35.72
# 5         Colorado    4.33          21.85         36.69        28.78
# 6         Delaware    2.98          37.41         21.84        24.22
# 7          Florida    3.13          13.27         23.94        36.48
# 8          Georgia   34.94          36.79         20.00         6.48
# 9            Idaho   22.53          39.29         28.63         6.29
# 10        Illinois    2.51          11.62         21.55        36.80
# 11         Indiana    7.07          32.19         31.47        19.55
# 12            Iowa    9.25          28.54         28.73        23.66
# 13          Kansas    0.35           7.56         19.33        41.90
# 14        Kentucky    5.22          19.40         29.33        27.95
# 15       Louisiana   20.48          43.30         22.07        11.19
# 16           Maine    7.21          39.21         21.46        21.10
# 17        Maryland    8.26          33.05         33.51        14.70
# 18        Michigan    0.82           8.39         20.48        36.36
# 19       Minnesota    3.70          16.86         24.57        34.19
# 20     Mississippi   14.44          29.38         32.75        13.70
# 21        Missouri    5.41          29.99         28.02        24.54
# 22         Montana    2.09          27.62         41.26        22.01
# 23        Nebraska   12.59          33.60         40.78         9.66
# 24          Nevada   27.07          31.93         32.39         5.55
# 25      New Mexico   17.99          37.08         31.70        11.58
# 26        New York    3.01           9.50         13.51        36.34
# 27  North Carolina   17.27          26.99         30.65        13.58
# 28    North Dakota    9.05          29.14         40.41        16.56
# 29        Oklahoma   12.79          43.89         29.08        10.45
# 30          Oregon   10.60          20.36         45.65        14.40
# 31  South Carolina    1.90          12.42         25.36        42.72
# 32    South Dakota    3.77          22.40         36.53        30.43
# 33       Tennessee    8.13          23.40         28.74        20.15
# 34           Texas    0.43           3.53         12.52        45.89
# 35            Utah    9.89          27.11         39.07        17.50
# 36         Vermont    8.76          41.01          5.53        35.25
# 37        Virginia    8.91          33.59         20.97        21.17
# 38      Washington   12.03          21.93         35.54        18.92
# 39   West Virginia   16.16          28.73         26.41        18.69
# 40       Wisconsin    4.38          24.00         36.60        21.51
# 41         Wyoming   14.38          30.37         36.88        12.68
#
#     % Graduate
# 0        10.60
# 1         5.45
# 2         3.79
# 3         4.82
# 4        42.88
# 5         8.35
# 6        13.54
# 7        23.17
# 8         1.79
# 9         3.26
# 10       27.51
# 11        9.72
# 12        9.82
# 13       30.86
# 14       18.10
# 15        2.96
# 16       11.03
# 17       10.48
# 18       33.95
# 19       20.68
# 20        9.73
# 21       12.05
# 22        7.02
# 23        3.37
# 24        3.05
# 25        1.65
# 26       37.64
# 27       11.50
# 28        4.83
# 29        3.79
# 30        8.98
# 31       17.60
# 32        6.86
# 33       19.58
# 34       37.63
# 35        6.43
# 36        9.45
# 37       15.37
# 38       11.57
# 39       10.01
# 40       13.52
# 41        5.70

# %%
# Display a stacked bar chart showing states on the x_axis and 100 on on the y-axis
# The education level types will make up the bar stacks
# Using Pandas to display horizontal bar chart showing discrete distributions

# Set x axis and tick locations
x_axis = np.arange(len(lowcrime_education_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
x_axis = lowcrime_education_df['State']
lowcrime_education_df.plot.bar(stacked=True)

plt.xticks(tick_locations, lowcrime_education_df["State"], rotation="vertical")

# Add Title and Labels to chart
plt.title("Education Level for Lowest Crime Rate City Within Each State")
plt.ylabel("Proportionate Education Leval")

# Save as a pd chart
plt.savefig("Low Crime/Results/lowcrime_education.png")
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Read High Crime Education Level csv into a new dataframe
highcrime_education_df = pd.read_csv('High Crime/Data/educationcrime.csv')
highcrime_education_df
# Out:
#              State  % None  % High School  % Associates  % Bachelors  \
# 0          Alabama   20.16          30.94         27.67        11.69
# 1           Alaska   17.15          34.35         30.72        11.75
# 2          Arizona   15.25          40.47         36.30         3.59
# 3         Arkansas   23.26          35.60         31.11         6.82
# 4       California    9.32          14.83         43.22        30.93
# 5      Connecticut   29.41          30.72         24.18         9.03
# 6         Delaware    8.37           9.69         23.79        36.12
# 7          Florida   45.42          31.70         18.18         3.54
# 8          Georgia   21.38          30.38         27.97        12.06
# 9            Idaho   15.06          36.32         38.25         6.94
# 10        Illinois   20.39          27.68         41.46         8.74
# 11         Indiana   22.40          38.41         25.87         9.16
# 12            Iowa   10.57          41.18         31.30        11.87
# 13          Kansas   12.46          26.82         32.38        18.77
# 14        Kentucky   16.37          33.43         29.96        13.04
# 15       Louisiana   18.02          28.37         24.99        17.37
# 16           Maine   12.12          45.42         33.80         8.33
# 17        Maryland   17.46          29.79         24.06        15.26
# 18        Michigan   29.47          37.88         27.56         2.84
# 19       Minnesota   29.84          41.13         23.39         3.87
# 20     Mississippi   25.36          38.37         24.02         7.83
# 21        Missouri   26.29          50.86         20.57         1.14
# 22         Montana   11.29          29.54         39.64        13.92
# 23        Nebraska    6.36          27.84         39.88        19.42
# 24   New Hampshire   12.64          43.02         30.05         9.52
# 25      New Jersey   17.14          55.71         17.14        10.00
# 26      New Mexico   18.60          50.47         18.60         7.67
# 27        New York   29.92          35.03         23.39         6.97
# 28  North Carolina   25.87          28.35         27.56        11.59
# 29    North Dakota    8.18          29.24         38.78        19.65
# 30            Ohio   14.75          34.01         33.81        11.16
# 31        Oklahoma   15.90          34.37         29.36        13.08
# 32          Oregon   11.17          34.84         36.68        11.27
# 33    Pennsylvania   14.19          46.17         30.28         6.14
# 34    Rhode Island   44.46          29.46         17.22         6.42
# 35  South Carolina   24.85          41.37         23.60         7.96
# 36    South Dakota   13.23          25.23         38.00        18.00
# 37       Tennessee   21.23          41.52         24.94         7.69
# 38           Texas   34.35          31.43         26.52         4.00
# 39            Utah   14.71          14.71         26.47        14.71
# 40         Vermont    7.10          33.87         31.76        20.37
# 41        Virginia   22.10          33.98         28.01         9.16
# 42      Washington   11.16          31.56         35.78        14.78
# 43   West Virginia   13.86          32.09         29.29        16.48
# 44       Wisconsin   17.86          29.62         29.23        15.36
# 45         Wyoming   13.53          38.62         38.36         7.11
#
#     % Graduate
# 0         9.54
# 1         6.04
# 2         4.39
# 3         3.21
# 4         1.69
# 5         6.66
# 6        22.03
# 7         1.17
# 8         8.21
# 9         3.42
# 10        1.74
# 11        4.16
# 12        5.08
# 13        9.56
# 14        7.21
# 15       11.25
# 16        0.33
# 17       13.43
# 18        2.25
# 19        1.77
# 20        4.42
# 21        1.14
# 22        5.60
# 23        6.50
# 24        4.76
# 25        0.00
# 26        4.65
# 27        4.69
# 28        6.64
# 29        4.15
# 30        6.27
# 31        7.29
# 32        6.05
# 33        3.22
# 34        2.44
# 35        2.21
# 36        5.54
# 37        4.62
# 38        3.70
# 39       29.41
# 40        6.90
# 41        6.74
# 42        6.72
# 43        8.30
# 44        7.92
# 45        2.39

# %%
# Display a stacked bar chart showing states on the x_axis and 100 on on the y-axis
# The education level types will make up the bar stacks
# Using Pandas to display horizontal bar chart showing discrete distributions

# Set x axis and tick locations
x_axis = np.arange(len(highcrime_education_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
x_axis = highcrime_education_df['State']
highcrime_education_df.plot.bar(stacked=True)

plt.xticks(tick_locations, highcrime_education_df["State"], rotation="vertical")

# Add Title and Labels to chart
plt.title("Education Level for Highest Crime Rate City Within Each State")
plt.ylabel("Proportionate Education Leval")

# Save as a pd chart
plt.savefig("High Crime/Results/highcrime_education.png")
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Read Low Crime Race csv into a new dataframe
lowcrime_race_df = pd.read_csv('Low Crime/Data/racecrime.csv')
lowcrime_race_df
# Out:
#              State  % Black  % Asian  % Native Hawaiian/Pacific Islander  \
# 0          Alabama     4.61     0.22                                0.00
# 1           Alaska     0.21     2.51                                0.00
# 2          Arizona     7.77     1.19                                0.25
# 3         Arkansas     2.06     0.45                                0.00
# 4       California     1.20    25.00                                0.00
# 5         Colorado     0.15     2.16                                0.11
# 6         Delaware     1.05     2.79                                0.00
# 7          Florida     5.60     6.69                                0.00
# 8          Georgia    21.95     0.22                                0.27
# 9            Idaho     0.00     1.03                                0.00
# 10         Indiana     4.97     2.05                                0.00
# 11            Iowa     1.10     2.75                                0.00
# 12          Kansas     0.28     0.73                                0.00
# 13        Kentucky     2.15     0.58                                0.00
# 14       Louisiana     8.76     0.00                                0.20
# 15           Maine     0.92     2.09                                0.00
# 16        Maryland     2.32     1.97                                0.00
# 17       Minnesota     1.53     8.85                                0.02
# 18     Mississippi    22.13     0.97                                0.00
# 19        Missouri     0.67     0.00                                0.00
# 20         Montana     0.00     1.51                                0.00
# 21        Nebraska     0.46     0.00                                0.00
# 22          Nevada     1.89     0.14                                0.59
# 23      New Mexico     0.00     0.00                                0.00
# 24        New York     0.65     5.20                                0.00
# 25  North Carolina     2.44     3.74                                0.00
# 26    North Dakota     0.12     0.73                                0.00
# 27        Oklahoma     3.09     1.16                                0.00
# 28          Oregon     1.63     1.25                                0.00
# 29  South Carolina     5.11     1.77                                0.00
# 30    South Dakota     1.26     0.00                                0.00
# 31       Tennessee     8.26     3.03                                0.00
# 32           Texas     0.89     4.22                                0.03
# 33            Utah     0.39     0.15                                0.00
# 34         Vermont     7.94     1.59                                0.00
# 35        Virginia     4.77     0.15                                0.00
# 36      Washington     1.76     0.71                                0.00
# 37   West Virginia    12.74     2.57                                0.00
# 38       Wisconsin     1.47     7.62                                0.16
# 39         Wyoming     0.00     0.25                                0.00
#
#     % White  % Hispanic/Latino  % American Indian/Alaskan Native  \
# 0     93.63               0.00                              0.00
# 1     68.38               1.42                             17.31
# 2     47.83              31.71                              2.10
# 3     89.19               5.62                              1.16
# 4     63.37               4.01                              0.00
# 5     80.68              11.31                              0.14
# 6     90.10               3.95                              0.79
# 7     66.98              17.90                              0.43
# 8     75.97               0.67                              0.00
# 9     64.80              29.45                              0.22
# 10    77.09               9.66                              0.36
# 11    92.23               1.61                              0.00
# 12    96.52               0.90                              0.13
# 13    95.22               0.67                              0.01
# 14    86.62               3.98                              0.03
# 15    95.03               0.74                              0.05
# 16    92.16               1.53                              0.00
# 17    84.23               2.70                              0.02
# 18    75.28               0.67                              0.00
# 19    94.37               2.62                              0.46
# 20    70.25               7.10                             14.55
# 21    87.52               9.49                              0.00
# 22    56.18              18.72                             12.13
# 23    45.06              38.25                              5.49
# 24    83.79               6.38                              0.27
# 25    89.64               4.18                              0.00
# 26    19.00               8.18                             67.30
# 27    72.18               4.75                             10.06
# 28    90.53               3.20                              3.39
# 29    88.01               3.70                              0.22
# 30    95.76               1.48                              0.67
# 31    78.73               5.12                              0.40
# 32    87.50               5.40                              0.14
# 33    83.92              11.51                              0.14
# 34    89.21               0.00                              0.00
# 35    86.50               4.86                              2.24
# 36    72.92              15.52                              0.12
# 37    71.71               9.42                              0.00
# 38    86.81               0.98                              0.00
# 39    76.31              16.17                              0.37
#
#     % Two or More  % Other
# 0            1.54     0.00
# 1           10.12     0.04
# 2            2.40     6.75
# 3            1.51     0.00
# 4            6.24     0.18
# 5            2.59     2.86
# 6            0.84     0.47
# 7            1.53     0.87
# 8            0.25     0.67
# 9            2.27     2.23
# 10           1.32     4.55
# 11           1.19     1.11
# 12           0.75     0.70
# 13           1.37     0.00
# 14           0.41     0.00
# 15           1.07     0.10
# 16           2.03     0.00
# 17           2.39     0.26
# 18           0.77     0.17
# 19           1.59     0.29
# 20           5.12     1.46
# 21           1.21     1.32
# 22           1.49     8.87
# 23           9.33     1.87
# 24           1.94     1.76
# 25           0.00     0.00
# 26           3.12     1.54
# 27           8.76     0.00
# 28           0.00     0.00
# 29           0.46     0.73
# 30           0.13     0.70
# 31           3.53     0.92
# 32           1.26     0.56
# 33           1.95     1.95
# 34           1.27     0.00
# 35           1.49     0.00
# 36           3.23     5.74
# 37           3.43     0.12
# 38           2.86     0.10
# 39           3.72     3.19

# %%
# Display a stacked bar chart showing states on the x_axis and 100 on on the y-axis
# The race types will make up the bar stacks
# Using Pandas to display horizontal bar chart showing discrete distributions

# Set x axis and tick locations
x_axis = np.arange(len(lowcrime_race_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
x_axis = lowcrime_race_df['State']
lowcrime_race_df.plot.bar(stacked=True)

plt.xticks(tick_locations, lowcrime_race_df["State"], rotation="vertical")

# Add Title and Labels to chart
plt.title("Racial Makeup for Lowest Crime Rate City Within Each State")
plt.ylabel("Proportionate Racial Makeup")

# Save as a pd chart
plt.savefig("Low Crime/Results/lowcrime_race.png")
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Read Low Crime Race csv into a new dataframe
highcrime_race_df = pd.read_csv('High Crime/Data/racecrime.csv')
highcrime_race_df
# Out:
#              State  % Black  % Asian  % Native Hawaiian/Pacific Islander  \
# 0          Alabama    49.91     1.68                                0.00
# 1           Alaska     0.68     1.37                                0.00
# 2          Arizona     0.62     0.00                                0.00
# 3         Arkansas    49.56     0.98                                0.12
# 4       California     1.02     8.33                                0.00
# 5      Connecticut    31.13     2.14                                0.03
# 6         Delaware     0.00     0.40                                0.00
# 7          Florida    49.51     0.30                                0.00
# 8          Georgia    74.74     0.18                                0.00
# 9            Idaho     0.22     0.88                                0.00
# 10        Illinois    67.92     0.40                                0.00
# 11         Indiana    12.53     1.50                                0.03
# 12            Iowa     4.21     0.66                                0.00
# 13          Kansas    11.02     4.87                                0.04
# 14        Kentucky    37.21     3.69                                0.00
# 15       Louisiana    64.17     0.95                                0.02
# 16           Maine     0.95     3.11                                0.00
# 17        Maryland    61.40     2.51                                0.06
# 18        Michigan    83.32     0.17                                0.00
# 19       Minnesota     4.00     4.72                                0.00
# 20     Mississippi    78.42     0.04                                0.00
# 21        Missouri    90.26     0.00                                0.00
# 22         Montana     0.11     0.63                                0.00
# 23        Nebraska     0.09     1.45                                0.00
# 24   New Hampshire     0.00     1.84                                0.00
# 25      New Jersey     0.00     0.00                                0.00
# 26        New York    21.86     0.47                                0.00
# 27  North Carolina    30.87     1.23                                0.21
# 28    North Dakota     0.71     0.00                                0.00
# 29            Ohio    25.56     1.34                                0.03
# 30        Oklahoma    10.70     1.32                                0.19
# 31          Oregon     0.78     0.00                                0.00
# 32    Pennsylvania    79.80     0.47                                0.00
# 33    Rhode Island    15.53     0.11                                0.00
# 34  South Carolina    64.25     0.00                                0.00
# 35    South Dakota     0.21     0.00                                0.00
# 36       Tennessee    51.58     0.20                                0.00
# 37           Texas     0.64     0.21                                0.00
# 38            Utah     0.00     0.00                                0.00
# 39         Vermont     0.67     1.29                                0.00
# 40        Virginia    75.76     1.30                                0.02
# 41      Washington    10.52    15.57                                5.18
# 42   West Virginia    25.65     2.90                                0.13
# 43       Wisconsin    36.56     3.35                                0.02
# 44         Wyoming     2.01     0.74                                0.00
#
#     % White  % Hispanic/Latino  % American Indian/Alaskan Native  \
# 0     43.28               1.57                              0.07
# 1     20.60               3.16                             66.33
# 2     32.92              52.21                              0.02
# 3     39.66               4.11                              0.51
# 4     25.20              52.85                              0.00
# 5     12.54              35.93                              0.32
# 6     97.20               2.40                              0.00
# 7      4.71              42.07                              0.35
# 8     12.29               7.14                              0.75
# 9     80.66               5.81                              8.24
# 10    27.28               0.47                              0.61
# 11    53.40              21.51                              0.04
# 12    87.24               3.28                              0.24
# 13    61.07              15.44                              0.96
# 14    41.70              10.51                              0.32
# 15    31.63               1.49                              0.23
# 16    95.36               0.00                              0.00
# 17    27.44               4.47                              0.28
# 18     6.70               3.42                              0.00
# 19    46.56              22.15                              2.36
# 20    18.78               1.23                              0.29
# 21     7.87               0.00                              0.00
# 22    55.31               6.52                             29.86
# 23    89.81               7.49                              0.20
# 24    96.19               1.45                              0.00
# 25    73.33              16.67                              0.00
# 26    14.29              38.72                              0.78
# 27    35.60              11.30                             10.62
# 28    91.70               3.44                              2.04
# 29    58.07               7.49                              0.30
# 30    59.74               8.90                              7.80
# 31    87.53               7.94                              0.14
# 32    11.69               5.69                              0.12
# 33    15.75              49.31                              0.63
# 34    10.93              12.41                              0.00
# 35    43.56               2.47                             35.84
# 36    41.96               3.35                              0.24
# 37     6.28              88.71                              0.00
# 38   100.00               0.00                              0.00
# 39    90.32               1.23                              0.06
# 40    15.38               4.16                              0.06
# 41    44.06              15.73                              1.76
# 42    66.63               0.90                              0.77
# 43    33.80              16.74                              0.54
# 44    77.20              13.31                              0.00
#
#     % Two or More  % Other
# 0            3.24     0.26
# 1            6.79     1.07
# 2            6.07     8.15
# 3            1.80     3.28
# 4            6.71     5.89
# 5            4.31    13.60
# 6            0.00     0.00
# 7            1.60     1.46
# 8            2.21     2.70
# 9            3.68     0.51
# 10           3.22     0.11
# 11           3.29     7.70
# 12           3.71     0.66
# 13           4.06     2.53
# 14           3.37     3.21
# 15           1.21     0.29
# 16           0.57     0.00
# 17           2.22     1.63
# 18           5.73     0.66
# 19           8.82    11.38
# 20           0.71     0.54
# 21           1.87     0.00
# 22           7.15     0.42
# 23           0.97     0.00
# 24           0.53     0.00
# 25           4.44     5.56
# 26           2.87    21.01
# 27           2.73     7.43
# 28           1.59     0.53
# 29           4.80     2.41
# 30           7.76     3.59
# 31           3.61     0.00
# 32           1.02     1.21
# 33           2.99    15.67
# 34           0.00    12.41
# 35          17.92     0.00
# 36           1.34     1.34
# 37           0.82     3.35
# 38           0.00     0.00
# 39           4.92     1.51
# 40           2.07     1.25
# 41           5.86     1.32
# 42           1.92     1.10
# 43           3.37     5.62
# 44           1.57     5.18

# %%
# Display a stacked bar chart showing states on the x_axis and 100 on on the y-axis
# The race types will make up the bar stacks
# Using Pandas to display horizontal bar chart showing discrete distributions

# Set x axis and tick locations
x_axis = np.arange(len(highcrime_race_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
x_axis = highcrime_race_df['State']
highcrime_race_df.plot.bar(stacked=True)

plt.xticks(tick_locations, highcrime_race_df["State"], rotation="vertical")

# Add Title and Labels to chart
plt.title("Racial Makeup for Highest Crime Rate City Within Each State")
plt.ylabel("Proportionate Racial Makeup")

# Save as a pd chart
plt.savefig("High Crime/Results/highcrime_race.png")
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Read Low Crime School Enrollment csv into a new dataframe
lowcrime_school_df = pd.read_csv('Low Crime/Data/schoolenrollmentcrime.csv')
lowcrime_school_df
# Out:
#              State  % Nursery-Pre-School  % Kindergarten  % 1st-4th  \
# 0          Alabama                  6.49           13.14      11.65
# 1           Alaska                  8.07            5.76      20.75
# 2          Arizona                  3.36            6.17      29.08
# 3         Arkansas                 10.87            5.05      27.86
# 4       California                 14.43            5.44      24.96
# 5         Colorado                 13.80            6.58      31.10
# 6         Delaware                  0.00            0.00      43.04
# 7          Florida                  9.21            4.18      27.22
# 8          Georgia                  3.79           12.31      25.57
# 9            Idaho                  5.42            4.30      33.93
# 10         Indiana                  7.42           10.68      23.74
# 11            Iowa                 12.28            7.63      31.98
# 12          Kansas                 10.39            7.20      19.11
# 13        Kentucky                  6.39            7.91      30.54
# 14       Louisiana                  4.75            0.00      28.00
# 15           Maine                 10.57            2.03       3.25
# 16        Maryland                 11.43           10.98      35.73
# 17       Minnesota                  9.01            4.80      26.22
# 18     Mississippi                  7.59            9.53      18.26
# 19        Missouri                  8.77           12.53      33.65
# 20         Montana                  0.00           11.20      28.09
# 21        Nebraska                  2.42           12.69      24.17
# 22          Nevada                  4.48            9.98      17.72
# 23      New Mexico                 10.02            7.07      39.69
# 24        New York                 11.30            5.76      28.69
# 25  North Carolina                  0.00            5.03      28.05
# 26    North Dakota                  6.95            6.46      23.59
# 27        Oklahoma                  6.30           10.36      30.43
# 28          Oregon                  0.00            0.00      57.91
# 29  South Carolina                  5.97            8.87      23.70
# 30    South Dakota                  9.90           11.35      26.65
# 31       Tennessee                  6.65            6.85      30.40
# 32           Texas                  8.83            5.82      27.12
# 33            Utah                  6.10            5.48      34.40
# 34         Vermont                  0.00            0.00      17.45
# 35        Virginia                  6.36            7.31      13.94
# 36      Washington                  6.35            3.62      24.11
# 37   West Virginia                 12.44            6.68      30.65
# 38       Wisconsin                  8.56            9.64      28.78
# 39         Wyoming                  5.94            2.43      35.82
#
#     % 5th-8th  % 9th-12th
# 0       48.92       19.80
# 1       27.67       37.75
# 2       28.22       33.17
# 3       27.18       29.03
# 4       27.40       27.78
# 5       29.49       19.02
# 6       27.85       29.11
# 7       31.86       27.53
# 8       32.39       25.95
# 9       30.37       25.98
# 10      26.22       31.93
# 11      18.63       29.47
# 12      33.38       29.92
# 13      32.70       22.46
# 14      43.75       23.50
# 15      48.51       35.64
# 16      18.81       23.04
# 17      27.09       32.88
# 18      38.13       26.49
# 19      24.05       21.00
# 20      32.02       28.68
# 21      24.17       36.56
# 22      26.88       40.94
# 23      11.00       32.22
# 24      30.62       23.62
# 25      35.20       31.72
# 26      36.35       26.66
# 27      27.97       24.93
# 28      21.94       20.14
# 29      35.12       26.34
# 30      28.90       23.19
# 31      29.75       26.36
# 32      30.46       27.77
# 33      32.63       21.39
# 34      53.69       28.86
# 35      31.39       41.00
# 36      39.37       26.54
# 37      37.97       12.26
# 38      27.78       25.24
# 39      23.85       31.97

# %%
# Display a stacked bar chart showing states on the x_axis and 100 on on the y-axis
# The school enrollment types will make up the bar stacks
# Using Pandas to display horizontal bar chart showing discrete distributions

# Set x axis and tick locations
x_axis = np.arange(len(lowcrime_school_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
x_axis = lowcrime_school_df['State']
lowcrime_school_df.plot.bar(stacked=True)

plt.xticks(tick_locations, lowcrime_school_df["State"], rotation="vertical")

# Add Title and Labels to chart
plt.title("School Enrollment for Lowest Crime Rate City Within Each State")
plt.ylabel("Proportionate School Enrollment Levels")

# Save as a pd chart
plt.savefig("Low Crime/Results/lowcrime_schoolenrollment.png")
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Read High Crime School Enrollment csv into a new dataframe
highcrime_school_df = pd.read_csv('HIgh Crime/Data/schoolenrollmentcrime.csv')
highcrime_school_df
# Out:
#              State  % Nursery-Pre-School  % Kindergarten  % 1st-4th  \
# 0          Alabama                 13.74           12.21      24.98
# 1           Alaska                  4.26            9.07      32.69
# 2          Arizona                  2.88            8.64      17.27
# 3         Arkansas                  6.50            7.05      18.37
# 4       California                  0.00            0.00      73.64
# 5      Connecticut                  9.21            7.63      27.65
# 6         Delaware                  0.00           13.33      13.33
# 7          Florida                 10.45            6.72      26.55
# 8          Georgia                 13.34            6.85      29.31
# 9            Idaho                  8.13            8.13      31.71
# 10        Illinois                 15.53            3.14      30.02
# 11         Indiana                  6.78            7.66      34.72
# 12            Iowa                  8.49           11.14      36.86
# 13          Kansas                  8.72            7.91      28.44
# 14        Kentucky                 11.33           20.69      19.70
# 15       Louisiana                 10.15            6.42      25.89
# 16           Maine                 30.00            0.00      30.00
# 17        Maryland                 10.88            8.32      27.35
# 18        Michigan                 16.07           10.18      27.06
# 19       Minnesota                  1.55            7.75      25.58
# 20     Mississippi                  8.68           16.16      24.93
# 21        Missouri                 14.29            0.00      33.33
# 22         Montana                  7.27            3.76      30.83
# 23        Nebraska                  8.71           15.27      27.47
# 24   New Hampshire                  0.00            0.00      60.66
# 25      New Jersey                  0.00            0.00      75.00
# 26        New York                  7.01            9.40      28.86
# 27  North Carolina                  8.08            7.79      28.94
# 28    North Dakota                 13.28            5.17      22.68
# 29            Ohio                  8.52            8.34      30.08
# 30        Oklahoma                 12.34            5.79      29.27
# 31          Oregon                  8.54            9.45      21.65
# 32    Pennsylvania                  5.82            4.07      33.29
# 33    Rhode Island                  9.31            9.73      23.56
# 34  South Carolina                  7.87            9.36       8.72
# 35    South Dakota                 12.14           11.56      35.84
# 36       Tennessee                 20.00            2.39      26.71
# 37           Texas                 12.52            8.21      33.11
# 38            Utah                  0.00            0.00       0.00
# 39         Vermont                 12.03            4.35      30.12
# 40        Virginia                  6.13            8.69      31.80
# 41      Washington                  5.16            8.37      29.17
# 42   West Virginia                  8.65            7.13      28.00
# 43       Wisconsin                  4.07           13.12      27.81
# 44         Wyoming                 12.62            5.11      36.90
#
#     % 5th-8th  % 9th-12th
# 0       24.44       24.63
# 1       26.92       27.06
# 2       30.61       40.61
# 3       38.05       30.03
# 4        5.43       20.93
# 5       25.05       30.47
# 6       53.33       20.00
# 7       29.09       27.19
# 8       28.99       21.51
# 9       30.08       21.95
# 10      29.32       21.99
# 11      27.14       23.71
# 12      20.76       22.76
# 13      27.29       27.63
# 14      25.62       22.66
# 15      32.08       25.46
# 16      13.33       26.67
# 17      26.37       27.09
# 18      24.12       22.57
# 19      43.41       21.71
# 20      30.14       20.09
# 21       2.38       50.00
# 22      30.58       27.57
# 23      24.90       23.65
# 24      22.95       16.39
# 25      25.00        0.00
# 26      30.68       24.06
# 27      23.26       31.94
# 28      29.61       29.26
# 29      25.27       27.79
# 30      25.22       27.38
# 31      27.74       32.62
# 32      29.01       27.81
# 33      31.00       26.41
# 34      26.81       47.23
# 35      17.34       23.12
# 36      20.99       29.91
# 37      23.89       22.26
# 38      31.25       68.75
# 39      29.01       24.49
# 40      21.35       32.04
# 41      25.44       31.86
# 42      27.09       29.15
# 43      26.70       28.29
# 44      24.60       20.77

# %%
# Display a stacked bar chart showing states on the x_axis and 100 on on the y-axis
# The school enrollment types will make up the bar stacks
# Using Pandas to display horizontal bar chart showing discrete distributions

# Set x axis and tick locations
x_axis = np.arange(len(highcrime_school_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
x_axis = highcrime_school_df['State']
highcrime_school_df.plot.bar(stacked=True)

plt.xticks(tick_locations, highcrime_school_df["State"], rotation="vertical")

# Add Title and Labels to chart
plt.title("School Enrollment for Highest Crime Rate City Within Each State")
plt.ylabel("Proportionate School Enrollment Levels")

# Save as a pd chart
plt.savefig("High Crime/Results/hichcrime_schoolenrollment.png")
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
