# %%
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets 
import pandas as pd
import time
import requests
from census import Census
#pd.set_option('display.max_rows', 30000)
# Census API Key
#from config import census_key
#c = Census(census_key, year=2015)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Lowest Crime Vs Education

# %%
lowest_crime = "lowest_crime.csv"
lowest_crime_df = pd.read_csv(lowest_crime)
#lowest_crime_df=lowest_crime_df[['City','Violent Crime Rate']]
education ="education.csv"
education_df=pd.read_csv(education)
#merge_df=pd.merge(left=lowest_crime_df, right=education_df, on='City', how='left')
#merge_df

# %%
education_df.shape
# Out:
# (29574, 8)

# %%
merge_df=pd.merge(left=lowest_crime_df, right=education_df, on=['City'], how='left')
merge_df
# Out:
#            State_x          City  Violent Crime Rate         State_y  \
# 0          ALABAMA          Argo            0.023730         Alabama
# 1           ALASKA      Wrangell            0.042535             NaN
# 2          ARIZONA       Buckeye            0.045362         Arizona
# 3          ARIZONA       Buckeye            0.045362            Iowa
# 4         ARKANSAS    Greenbrier            0.018730        Arkansas
# ..             ...           ...                 ...             ...
# 173  WEST VIRGINIA  Charles Town            0.034388   West Virginia
# 174      WISCONSIN      Onalaska            0.005397           Texas
# 175      WISCONSIN      Onalaska            0.005397      Washington
# 176      WISCONSIN      Onalaska            0.005397       Wisconsin
# 177        WYOMING       Worland            0.018744         Wyoming
#
#      Population    None  High School  Associates  Bachelors  Graduate
# ...
